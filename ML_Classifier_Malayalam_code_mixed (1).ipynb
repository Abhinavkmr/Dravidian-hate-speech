# %%
import pandas as pd 
data_train = pd.read_excel('/content/drive/MyDrive/HASOC_2021/HASOC_Dravidian/Task2_Tamil_malayalam_code_mixed/Malayalam_codemixed/Malayalam_offensive_data_Training-YT.xlsx', names=['id','text','label'])
data_val = pd.read_csv('/content/drive/MyDrive/HASOC_2021/HASOC_Dravidian/Task2_Tamil_malayalam_code_mixed/Malayalam_codemixed/malayalam_hasoc_tanglish_test_withlabels.tsv', sep = '\t', names=['id','text','label'])
data_test = pd.read_csv('/content/drive/MyDrive/HASOC_2021/HASOC_Dravidian/Task2_Tamil_malayalam_code_mixed/Malayalam_codemixed/mal-offensive-withoutlabels - Sheet1.tsv', sep = '\t')

# %%
data_train = data_train.dropna()

# %%
data_train.head()
# Out:
#          id                                               text label
# 0  MA_YT001                   Thaankal enthaan cheyyarullath?😛   NOT
# 1  MA_YT002  Ee theetam WCC feminichigalude news aarkk vena...   OFF
# 2  MA_YT003  fukru nem tiktok oolakale vilich charcha nadat...   OFF
# 3  MA_YT004  Aashiq abu produce cheytharunnel ee problems u...   NOT
# 4  MA_YT005  Pennungal oru team aayal ath moonjum ennu epoo...   OFF

# %%
data_val = data_val.dropna()

# %%
data_val.head()
# Out:
#           id                                               text label
# 0  MA_YT5000               Chenkol vendath thanne aayirunnu....   NOT
# 1  MA_YT5001              Sundardasinte bhakshnam vakkukal ano?   NOT
# 2  MA_YT5002  Akasha dooth oru copy adi movie anu 'Who will ...   NOT
# 3  MA_YT5003  Purath onnum pondade... oru pennum payyanum on...   NOT
# 4  MA_YT5004  Avasanam Fahad oru Oscar medikkumbazhum lalett...   NOT

# %%
data_test.head()
# Out:
#           ID                                             Tweets
# 0  MA_YT6001  athe beharyku deputationil pokam pinarai vijay...
# 1  MA_YT6002  USER cheruparamadathil than thinnunnath alla p...
# 2  MA_YT6003  USER cheruparamadathilpinaraayi shournuril oru...
# 3  MA_YT6004  USER vk pinarai thinnunnathu ninte okke theett...
# 4  MA_YT6005  USER george thante ammade poottile pooda kalay...

# %%
data_train.shape, data_val.shape, data_test.shape
# Out:
# ((3999, 3), (951, 3), (999, 2))

# %%
data_train['label'].value_counts()
# Out:
# NOT    2047
# OFF    1952
# Name: label, dtype: int64

# %%
data_val['label'].value_counts()
# Out:
# OFF    478
# NOT    473
# Name: label, dtype: int64

# %%
from sklearn import preprocessing
import numpy as np

le = preprocessing.LabelEncoder()

le.fit(data_train['label'])
print(le.classes_)

y_train_index = le.transform(data_train['label'])
y_val_index = le.transform(data_val['label'])
# Out:
# ['NOT' 'OFF']

# %% [markdown]
# For word = ngram_range (1,3)
# For char = ngram_range (1,6)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidfvec = TfidfVectorizer(ngram_range=(1,6), analyzer = 'char_wb', max_features = 30000)
#tfidfvec = TfidfVectorizer(ngram_range=(1,3), max_features = 30000)
tfidf_train = tfidfvec.fit_transform(data_train['text'])
tfidf_val = tfidfvec.transform(data_val['text'])

# %%
tfidfvec.get_feature_names()
# Out:
# [' ',
#  ' !',
#  ' ! ',
#  ' !!',
#  ' !! ',
#  ' "',
#  ' &',
#  ' & ',
#  " '",
#  ' (',
#  ' (a',
#  ' ,',
#  ' , ',
#  ' ,,',
#  ' ,,,',
#  ' ,a',
#  ' ,e',
#  ' ,k',
#  ' -',
#  ' .',
#  ' . ',
#  ' ..',
#  ' .. ',
#  ' ...',
#  ' ... ',
#  ' ....',
#  ' .... ',
#  ' .....',
#  ' ...e',
#  ' ..a',
#  ' ..e',
#  ' ..n',
#  ' ..p',
#  ' ..s',
#  ' .a',
#  ' .e',
#  ' .i',
#  ' .k',
#  ' .m',
#  ' .ma',
#  ' .n',
#  ' .ni',
#  ' .nin',
#  ' .o',
#  ' .p',
#  ' .pa',
#  ' 1',
#  ' 1 ',
#  ' 10',
#  ' 10 ',
#  ' 100',
#  ' 100 ',
#  ' 100%',
#  ' 100% ',
#  ' 1000',
#  ' 15',
#  ' 15 ',
#  ' 2',
#  ' 2 ',
#  ' 20',
#  ' 24',
#  ' 3',
#  ' 3 ',
#  ' 30',
#  ' 4',
#  ' 5',
#  ' 5 ',
#  ' 50',
#  ' 50 ',
#  ' 500',
#  ' 6',
#  ' 6 ',
#  ' 7',
#  ' 8',
#  ' 9',
#  ' :',
#  ' :d',
#  ' :d ',
#  ' ?',
#  ' ? ',
#  ' ??',
#  ' ???',
#  ' ??? ',
#  ' @',
#  ' @u',
#  ' @us',
#  ' @use',
#  ' @user',
#  ' a',
#  ' a ',
#  ' aa',
#  ' aa ',
#  ' aaa',
#  ' aaa ',
#  ' aaa.',
#  ' aaaa',
#  ' aaaa ',
#  ' aaan',
#  ' aaanu',
#  ' aaar',
#  ' aaay',
#  ' aad',
#  ' aada',
#  ' aadh',
#  ' aadhy',
#  ' aadi',
#  ' aady',
#  ' aadya',
#  ' aag',
#  ' aah',
#  ' aah ',
#  ' aahn',
#  ' aai',
#  ' aait',
#  ' aait ',
#  ' aak',
#  ' aaka',
#  ' aakan',
#  ' aaki',
#  ' aaki ',
#  ' aakiy',
#  ' aakk',
#  ' aakki',
#  ' aaku',
#  ' aakum',
#  ' aal',
#  ' aal ',
#  ' aala',
#  ' aalan',
#  ' aale',
#  ' aalk',
#  ' aalka',
#  ' aalkk',
#  ' aalo',
#  ' aalu',
#  ' aaluk',
#  ' aan',
#  ' aan ',
#  ' aan.',
#  ' aan. ',
#  ' aan..',
#  ' aana',
#  ' aanal',
#  ' aane',
#  ' aane ',
#  ' aanel',
#  ' aanen',
#  ' aann',
#  ' aann ',
#  ' aanno',
#  ' aano',
#  ' aano ',
#  ' aano.',
#  ' aano?',
#  ' aanu',
#  ' aanu ',
#  ' aanu.',
#  ' aanun',
#  ' aar',
#  ' aara',
#  ' aara ',
#  ' aarad',
#  ' aaran',
#  ' aare',
#  ' aarel',
#  ' aaren',
#  ' aarey',
#  ' aari',
#  ' aark',
#  ' aarkk',
#  ' aarku',
#  ' aaro',
#  ' aaru',
#  ' aaru ',
#  ' aarum',
#  ' aas',
#  ' aasa',
#  ' aash',
#  ' aashi',
#  ' aasw',
#  ' aaswa',
#  ' aav',
#  ' aava',
#  ' aavan',
#  ' aavu',
#  ' aavum',
#  ' aay',
#  ' aaya',
#  ' aaya ',
#  ' aayaa',
#  ' aayal',
#  ' aayat',
#  ' aaye',
#  ' aayi',
#  ' aayi ',
#  ' aayir',
#  ' aayit',
#  ' aayr',
#  ' aayu',
#  ' ab',
#  ' aba',
#  ' abd',
#  ' abdu',
#  ' abdul',
#  ' abh',
#  ' abha',
#  ' abham',
#  ' abhi',
#  ' abhim',
#  ' abhin',
#  ' abhip',
#  ' abi',
#  ' abin',
#  ' abina',
#  ' abip',
#  ' abipr',
#  ' abu',
#  ' abu ',
#  ' abuv',
#  ' abuvi',
#  ' abv',
#  ' abvp',
#  ' abvp ',
#  ' ac',
#  ' acc',
#  ' acce',
#  ' acco',
#  ' accou',
#  ' ach',
#  ' acha',
#  ' achan',
#  ' act',
#  ' acti',
#  ' acto',
#  ' ad',
#  ' ada',
#  ' ada ',
#  ' adan',
#  ' adang',
#  ' ade',
#  ' adh',
#  ' adha',
#  ' adhe',
#  ' adheh',
#  ' adhi',
#  ' adhik',
#  ' adhu',
#  ' adhy',
#  ' adhya',
#  ' adi',
#  ' adi ',
#  ' adic',
#  ' adich',
#  ' adik',
#  ' adika',
#  ' adikk',
#  ' adiku',
#  ' adim',
#  ' adima',
#  ' adip',
#  ' adipo',
#  ' adiy',
#  ' ado',
#  ' adu',
#  ' adut',
#  ' aduth',
#  ' adv',
#  ' ady',
#  ' adya',
#  ' adyam',
#  ' ae',
#  ' af',
#  ' ag',
#  ' age',
#  ' agen',
#  ' agr',
#  ' agra',
#  ' agrah',
#  ' ah',
#  ' ah ',
#  ' aha',
#  ' ahan',
#  ' ahang',
#  ' ahank',
#  ' ahn',
#  ' ai',
#  ' aj',
#  ' ak',
#  ' aka',
#  ' akan',
#  ' akan ',
#  ' akat',
#  ' akath',
#  ' ake',
#  ' aki',
#  ' akk',
#  ' akr',
#  ' akra',
#  ' akram',
#  ' aku',
#  ' akum',
#  ' akum ',
#  ' akun',
#  ' al',
#  ' ala',
#  ' ala ',
#  ' alat',
#  ' alath',
#  ' alav',
#  ' alava',
#  ' ale',
#  ' ale ',
#  ' ali',
#  ' alk',
#  ' alka',
#  ' alkar',
#  ' all',
#  ' all ',
#  ' alla',
#  ' alla ',
#  ' alla,',
#  ' alla.',
#  ' allaa',
#  ' allad',
#  ' allah',
#  ' allal',
#  ' allam',
#  ' allan',
#  ' allat',
#  ' allav',
#  ' alle',
#  ' alle ',
#  ' alle.',
#  ' alle?',
#  ' allel',
#  ' allen',
#  ' alo',
#  ' aloo',
#  ' aloor',
#  ' alu',
#  ' aluk',
#  ' aluka',
#  ' am',
#  ' amb',
#  ' ambi',
#  ' ambil',
#  ' ame',
#  ' amer',
#  ' ameri',
#  ' ami',
#  ' amit',
#  ' amm',
#  ' amma',
#  ' amma ',
#  ' ammak',
#  ' ammam',
#  ' amman',
#  ' ammay',
#  ' amme',
#  ' amme ',
#  ' ammed',
#  ' ammm',
#  ' an',
#  ' ana',
#  ' anal',
#  ' anall',
#  ' anan',
#  ' and',
#  ' and ',
#  ' andi',
#  ' andi ',
#  ' ane',
#  ' ane ',
#  ' anel',
#  ' anen',
#  ' anenn',
#  ' ang',
#  ' anga',
#  ' angan',
#  ' ange',
#  ' angee',
#  ' angn',
#  ' angne',
#  ' ango',
#  ' angot',
#  ' angu',
#  ' angu ',
#  ' ani',
#  ' anik',
#  ' ann',
#  ' ann ',
#  ' anna',
#  ' anna ',
#  ' annal',
#  ' annan',
#  ' anne',
#  ' anne ',
#  ' annen',
#  ' anno',
#  ' anno ',
#  ' annu',
#  ' annu ',
#  ' annu.',
#  ' ano',
#  ' ano ',
#  ' ano.',
#  ' ano?',
#  ' ano? ',
#  ' anod',
#  ' ant',
#  ' ante',
#  ' ante ',
#  ' anth',
#  ' antha',
#  ' anu',
#  ' anu ',
#  ' anu.',
#  ' anu..',
#  ' anub',
#  ' anubh',
#  ' anug',
#  ' anus',
#  ' anuv',
#  ' anuva',
#  ' anw',
#  ' anwe',
#  ' anwes',
#  ' any',
#  ' anya',
#  ' ap',
#  ' apa',
#  ' apam',
#  ' apama',
#  ' apar',
#  ' apo',
#  ' apo ',
#  ' apol',
#  ' apol ',
#  ' app',
#  ' appa',
#  ' appan',
#  ' appo',
#  ' appo ',
#  ' appol',
#  ' appoz',
#  ' ar',
#  ' ara',
#  ' araa',
#  ' arab',
#  ' arabi',
#  ' arad',
#  ' arada',
#  ' aran',
#  ' are',
#  ' are ',
#  ' aren',
#  ' areng',
#  ' arey',
#  ' areyu',
#  ' arh',
#  ' ari',
#  ' arin',
#  ' arinj',
#  ' ariv',
#  ' ariy',
#  ' ariya',
#  ' ariyi',
#  ' ariyu',
#  ' arj',
#  ' arju',
#  ' ark',
#  ' arkk',
#  ' aro',
#  ' arr',
#  ' arre',
#  ' art',
#  ' art ',
#  ' arth',
#  ' artha',
#  ' arti',
#  ' aru',
#  ' arum',
#  ' arum ',
#  ' arun',
#  ' ary',
#  ' arya',
#  ' arya ',
#  ' as',
#  ' as ',
#  ' ash',
#  ' ashi',
#  ' ashik',
#  ' ashiq',
#  ' asi',
#  ' asia',
#  ' aso',
#  ' asoo',
#  ' ass',
#  ' asu',
#  ' asuk',
#  ' asuka',
#  ' at',
#  ' ath',
#  ' ath ',
#  ' atha',
#  ' atha ',
#  ' athaa',
#  ' athal',
#  ' athan',
#  ' athay',
#  ' athe',
#  ' athe ',
#  ' athe.',
#  ' athen',
#  ' athi',
#  ' athik',
#  ' athil',
#  ' athin',
#  ' athir',
#  ' athm',
#  ' atho',
#  ' atho ',
#  ' athok',
#  ' athon',
#  ' athor',
#  ' athr',
#  ' athra',
#  ' athre',
#  ' athu',
#  ' athu ',
#  ' athuk',
#  ' athum',
#  ' athup',
#  ' athy',
#  ' athya',
#  ' atr',
#  ' att',
#  ' atta',
#  ' au',
#  ' aun',
#  ' aunt',
#  ' aunty',
#  ' aus',
#  ' aust',
#  ' av',
#  ' ava',
#  ' avak',
#  ' avaka',
#  ' aval',
#  ' aval ',
#  ' avala',
#  ' avald',
#  ' avale',
#  ' avalk',
#  ' avalo',
#  ' avalu',
#  ' avan',
#  ' avan ',
#  ' avana',
#  ' avand',
#  ' avane',
#  ' avanm',
#  ' avant',
#  ' avanu',
#  ' avar',
#  ' avar ',
#  ' avara',
#  ' avard',
#  ' avare',
#  ' avark',
#  ' avaro',
#  ' avaru',
#  ' avas',
#  ' avasa',
#  ' avast',
#  ' avasy',
#  ' avat',
#  ' avath',
#  ' avd',
#  ' avde',
#  ' avde ',
#  ' avi',
#  ' avid',
#  ' avida',
#  ' avide',
#  ' avis',
#  ' avish',
#  ' avl',
#  ' avld',
#  ' avlde',
#  ' avn',
#  ' avr',
#  ' avs',
#  ' avu',
#  ' avum',
#  ' aw',
#  ' awa',
#  ' awar',
#  ' award',
#  ' ay',
#  ' aya',
#  ' aya ',
#  ' ayaa',
#  ' ayaal',
#  ' ayac',
#  ' ayach',
#  ' ayak',
#  ' ayakk',
#  ' ayal',
#  ' ayal ',
#  ' ayall',
#  ' ayalu',
#  ' ayat',
#  ' ayath',
#  ' ayi',
#  ' ayi ',
#  ' ayik',
#  ' ayin',
#  ' ayin ',
#  ' ayir',
#  ' ayiri',
#  ' ayiru',
#  ' ayit',
#  ' ayitt',
#  ' ayo',
#  ' ayy',
#  ' ayya',
#  ' ayyap',
#  ' ayye',
#  ' ayyo',
#  ' ayyo ',
#  ' ayyy',
#  ' az',
#  ' azh',
#  ' azhi',
#  ' azhic',
#  ' b',
#  ' b ',
#  ' ba',
#  ' baa',
#  ' baak',
#  ' baaki',
#  ' bab',
#  ' babu',
#  ' babu ',
#  ' bac',
#  ' back',
#  ' bad',
#  ' bag',
#  ' bah',
#  ' bahu',
#  ' bahum',
#  ' bak',
#  ' baki',
#  ' baki ',
#  ' bakk',
#  ' bakki',
#  ' bal',
#  ' bala',
#  ' balan',
#  ' ban',
#  ' band',
#  ' bandh',
#  ' bang',
#  ' bar',
#  ' bart',
#  ' barth',
#  ' bas',
#  ' bash',
#  ' bav',
#  ' bay',
#  ' baya',
#  ' be',
#  ' be ',
#  ' bea',
#  ' beac',
#  ' beach',
#  ' beau',
#  ' beaut',
#  ' bee',
#  ' bes',
#  ' best',
#  ' best ',
#  ' bet',
#  ' bh',
#  ' bha',
#  ' bhag',
#  ' bhaga',
#  ' bhai',
#  ' bhai ',
#  ' bhai.',
#  ' bhak',
#  ' bhan',
#  ' bhar',
#  ' bhara',
#  ' bhari',
#  ' bhart',
#  ' bhary',
#  ' bhas',
#  ' bhasi',
#  ' bhav',
#  ' bhavi',
#  ' bhay',
#  ' bhaya',
#  ' bhe',
#  ' bhed',
#  ' bhee',
#  ' bhees',
#  ' bho',
#  ' bhoo',
#  ' bhoom',
#  ' bhu',
#  ' bhud',
#  ' bhudh',
#  ' bhudi',
#  ' bi',
#  ' big',
#  ' big ',
#  ' bij',
#  ' biju',
#  ' biju ',
#  ' bik',
#  ' bir',
#  ' biri',
#  ' biriy',
#  ' bj',
#  ' bjp',
#  ' bjp ',
#  ' bl',
#  ' bla',
#  ' ble',
#  ' bles',
#  ' bless',
#  ' blo',
#  ' bloo',
#  ' blood',
#  ' bo',
#  ' bod',
#  ' bodh',
#  ' bodha',
#  ' body',
#  ' body ',
#  ' bom',
#  ' bomb',
#  ' boo',
#  ' book',
#  ' bor',
#  ' bore',
#  ' bore ',
#  ' bos',
#  ' boss',
#  ' boss ',
#  ' bossi',
#  ' bot',
#  ' both',
#  ' box',
#  ' boy',
#  ' br',
#  ' bra',
#  ' brah',
#  ' brahm',
#  ' bran',
#  ' bri',
#  ' brit',
#  ' briti',
#  ' bro',
#  ' bro ',
#  ' bro.',
#  ' bro. ',
#  ' bro..',
#  ' broo',
#  ' brot',
#  ' broth',
#  ' bru',
#  ' bu',
#  ' bud',
#  ' budh',
#  ' budhi',
#  ' bus',
#  ' busi',
#  ' busin',
#  ' but',
#  ' but ',
#  ' by',
#  ' by ',
#  ' c',
#  ' c ',
#  ' ca',
#  ' cal',
#  ' call',
#  ' cam',
#  ' came',
#  ' camer',
#  ' can',
#  ' car',
#  ' cas',
#  ' case',
#  ' case ',
#  ' cash',
#  ' cash ',
#  ' ce',
#  ' cel',
#  ' cele',
#  ' celeb',
#  ' ch',
#  ' cha',
#  ' chaa',
#  ' chaak',
#  ' chaan',
#  ' chaav',
#  ' chad',
#  ' chadi',
#  ' chai',
#  ' chait',
#  ' chak',
#  ' chaka',
#  ' chal',
#  ' cham',
#  ' chan',
#  ' chana',
#  ' chanc',
#  ' chand',
#  ' chane',
#  ' chang',
#  ' chank',
#  ' chann',
#  ' chant',
#  ' char',
#  ' chara',
#  ' charc',
#  ' chari',
#  ' chat',
#  ' chath',
#  ' chatt',
#  ' chav',
#  ' chava',
#  ' chave',
#  ' chavi',
#  ' chavu',
#  ' chay',
#  ' chaya',
#  ' chayy',
#  ' che',
#  ' che ',
#  ' chea',
#  ' cheap',
#  ' chec',
#  ' chech',
#  ' chee',
#  ' cheet',
#  ' cheg',
#  ' chegu',
#  ' chei',
#  ' cheit',
#  ' chek',
#  ' chekk',
#  ' cheku',
#  ' chel',
#  ' chela',
#  ' chell',
#  ' chen',
#  ' chenn',
#  ' cher',
#  ' chera',
#  ' cheri',
#  ' chert',
#  ' cheru',
#  ' chet',
#  ' cheta',
#  ' chett',
#  ' chev',
#  ' chevi',
#  ' chey',
#  ' cheya',
#  ' cheyd',
#  ' cheyi',
#  ' cheyt',
#  ' cheyu',
#  ' cheyy',
#  ' chi',
#  ' chil',
#  ' chila',
#  ' chin',
#  ' china',
#  ' chind',
#  ' chint',
#  ' chir',
#  ' chiri',
#  ' chit',
#  ' chith',
#  ' chiy',
#  ' cho',
#  ' chod',
#  ' chodh',
#  ' chodi',
#  ' chody',
#  ' choi',
#  ' choic',
#  ' choo',
#  ' chood',
#  ' chor',
#  ' chora',
#  ' chori',
#  ' chot',
#  ' choth',
#  ' chr',
#  ' chri',
#  ' chris',
#  ' chu',
#  ' chum',
#  ' chumm',
#  ' chun',
#  ' chund',
#  ' chur',
#  ' churu',
#  ' chut',
#  ' chutt',
#  ' chuv',
#  ' chuva',
#  ' chy',
#  ' chyd',
#  ' chyt',
#  ' chyth',
#  ' ci',
#  ' cig',
#  ' ciga',
#  ' cigar',
#  ' cin',
#  ' cine',
#  ' cinem',
#  ' cini',
#  ' cinim',
#  ' cl',
#  ' cla',
#  ' clas',
#  ' class',
#  ' cle',
#  ' clea',
#  ' clear',
#  ' cli',
#  ' cm',
#  ' cm ',
#  ' cmn',
#  ' cmnt',
#  ' cmnt ',
#  ' cmnts',
#  ' co',
#  ' col',
#  ' coll',
#  ' colle',
#  ' colo',
#  ' colon',
#  ' color',
#  ' com',
#  ' come',
#  ' comed',
#  ' comm',
#  ' comme',
#  ' commi',
#  ' commu',
#  ' comp',
#  ' compa',
#  ' con',
#  ' conf',
#  ' cong',
#  ' congr',
#  ' cont',
#  ' conte',
#  ' cop',
#  ' copy',
#  ' cor',
#  ' coro',
#  ' coron',
#  ' corr',
#  ' corre',
#  ' cou',
#  ' coun',
#  ' cov',
#  ' cove',
#  ' cover',
#  ' covi',
#  ' covid',
#  ' cp',
#  ' cpi',
#  ' cpim',
#  ' cpim ',
#  ' cpm',
#  ' cpm ',
#  ' cr',
#  ' cre',
#  ' cri',
#  ' crim',
#  ' crimi',
#  ' cris',
#  ' crist',
#  ' cu',
#  ' cul',
#  ' cult',
#  ' cultu',
#  ' cur',
#  ...]

# %%
tfidf_train.shape
# Out:
# (3999, 30000)

# %%
x_train = tfidf_train
x_test = tfidf_val
y_train = data_train['label']
y_test = data_val['label']

# %%
    from sklearn import metrics
    from sklearn.svm import SVC
    model_SVM = SVC(probability=True)
    model_SVM.fit(x_train, y_train)
    y_pred_SVM = model_SVM.predict(x_test)
    print("SVM")
    print(metrics.classification_report(y_test, y_pred_SVM))
    
    from sklearn.ensemble import RandomForestClassifier
    rf = RandomForestClassifier()
    rf.fit(x_train,y_train)
    y_pred_rf = rf.predict(x_test)
    print("random")
    print(metrics.classification_report(y_test, y_pred_rf))
    
    from sklearn.linear_model import LogisticRegression
    LR = LogisticRegression()
    LR.fit(x_train,y_train)
    y_pred_LR = LR.predict(x_test)
    print("Logistic Regression")
    print(metrics.classification_report(y_test, y_pred_LR ))
    
    from sklearn.neighbors import KNeighborsClassifier
    neigh = KNeighborsClassifier()
    neigh.fit(x_train,y_train)
    y_pred_KNN = neigh.predict(x_test)
    print("KNN")
    print(metrics.classification_report(y_test, y_pred_KNN ))
    
    from sklearn.naive_bayes import GaussianNB
    naive = GaussianNB()
    naive.fit(x_train.toarray(),y_train)
    y_pred_naive = naive.predict(x_test.toarray())
    print("Naive Bayes")
    print(metrics.classification_report(y_test, y_pred_naive ))
    
    from sklearn.ensemble import GradientBoostingClassifier
    gradient = GradientBoostingClassifier()
    gradient.fit(x_train,y_train)
    y_pred_gradient = gradient.predict(x_test)
    print("Gradient Boosting")
    print(metrics.classification_report(y_test, y_pred_gradient ))
    
    from sklearn.tree import DecisionTreeClassifier
    decision = DecisionTreeClassifier()
    decision.fit(x_train,y_train)
    y_pred_decision = decision.predict(x_test)
    print("Decision Tree")
    print(metrics.classification_report(y_test, y_pred_decision ))

    from sklearn.ensemble import AdaBoostClassifier
    AdaBoostclf = AdaBoostClassifier()
    AdaBoostclf.fit(x_train,y_train)
    y_pred_AdaBoostclf = AdaBoostclf.predict(x_test)
    print("AdaBoost classifier")
    print(metrics.classification_report(y_test, y_pred_AdaBoostclf ))
# Out:
# SVM
#               precision    recall  f1-score   support
#
#          NOT       0.73      0.84      0.78       473
#          OFF       0.81      0.70      0.75       478
#
#     accuracy                           0.77       951
#    macro avg       0.77      0.77      0.77       951
# weighted avg       0.77      0.77      0.77       951
#
# random
#               precision    recall  f1-score   support
#
#          NOT       0.74      0.85      0.79       473
#          OFF       0.82      0.70      0.76       478
#
#     accuracy                           0.77       951
#    macro avg       0.78      0.77      0.77       951
# weighted avg       0.78      0.77      0.77       951
#
# Logistic Regression
#               precision    recall  f1-score   support
#
#          NOT       0.75      0.83      0.79       473
#          OFF       0.81      0.73      0.77       478
#
#     accuracy                           0.78       951
#    macro avg       0.78      0.78      0.78       951
# weighted avg       0.78      0.78      0.78       951
#
# KNN
#               precision    recall  f1-score   support
#
#          NOT       0.67      0.53      0.59       473
#          OFF       0.61      0.74      0.67       478
#
#     accuracy                           0.63       951
#    macro avg       0.64      0.63      0.63       951
# weighted avg       0.64      0.63      0.63       951
#
# Naive Bayes
#               precision    recall  f1-score   support
#
#          NOT       0.72      0.69      0.70       473
#          OFF       0.70      0.73      0.72       478
#
#     accuracy                           0.71       951
#    macro avg       0.71      0.71      0.71       951
# weighted avg       0.71      0.71      0.71       951
#
# Gradient Boosting
#               precision    recall  f1-score   support
#
#          NOT       0.69      0.81      0.75       473
#          OFF       0.77      0.64      0.70       478
#
#     accuracy                           0.73       951
#    macro avg       0.73      0.73      0.72       951
# weighted avg       0.73      0.73      0.72       951
#
# Decision Tree
#               precision    recall  f1-score   support
#
#          NOT       0.62      0.62      0.62       473
#          OFF       0.62      0.62      0.62       478
#
#     accuracy                           0.62       951
#    macro avg       0.62      0.62      0.62       951
# weighted avg       0.62      0.62      0.62       951
#
# AdaBoost classifier
#               precision    recall  f1-score   support
#
#          NOT       0.67      0.75      0.71       473
#          OFF       0.72      0.63      0.67       478
#
#     accuracy                           0.69       951
#    macro avg       0.69      0.69      0.69       951
# weighted avg       0.69      0.69      0.69       951

# %%
tfidf_test = tfidfvec.transform(data_test['Tweets'])

# %%
y_pred_model_SVM_prob = model_SVM.predict_proba(tfidf_test)

# %%
y_pred_model_SVM_prob
# Out:
# array([[0.69326411, 0.30673589],
#        [0.57313472, 0.42686528],
#        [0.91266183, 0.08733817],
#        ...,
#        [0.08842016, 0.91157984],
#        [0.79394526, 0.20605474],
#        [0.63443342, 0.36556658]])

# %%
df_y_pred_model_SVM_prob= pd.DataFrame(y_pred_model_SVM_prob, columns = ['NOT','OFF'])

# %%
df_y_pred_model_SVM_prob.to_csv('/content/drive/MyDrive/HASOC_2021/HASOC_Dravidian/Task2_Tamil_malayalam_code_mixed/Malayalam_codemixed/SVM_char_mal_1-6_gram_77.csv',index = False)

# %%
y_pred_rf_prob = rf.predict_proba(tfidf_test)

# %%
df_y_pred_rf_prob= pd.DataFrame(y_pred_rf_prob, columns = ['NOT','OFF'])

# %%
df_y_pred_rf_prob.to_csv('/content/drive/MyDrive/HASOC_2021/HASOC_Dravidian/Task2_Tamil_malayalam_code_mixed/Malayalam_codemixed/RF_char_mal_1-6_gram_77.csv', index = False)

# %%
y_pred_LR_prob = LR.predict_proba(tfidf_test)

# %%
df_y_pred_LR_prob= pd.DataFrame(y_pred_LR_prob, columns = ['NOT','OFF'])

# %%
df_y_pred_LR_prob.to_csv('/content/drive/MyDrive/HASOC_2021/HASOC_Dravidian/Task2_Tamil_malayalam_code_mixed/Malayalam_codemixed/LR_char_mal_1-6_gram_78.csv', index = False)
